# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en_core_web_lg==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 1.3 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_lg==2.2.5) (2.2.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (7.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (4.62.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.23.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.19.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (4.6.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.5.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.4)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Load and Run Model

# %%
import gensim
import tensorflow as tf
from keras.models import load_model

model_prediction = load_model('/content/drive/MyDrive/Colab files/final_model.h5', compile=False)
vocab = gensim.models.KeyedVectors.load("/content/drive/MyDrive/Colab files/final_vocab_model.bin")

# %% [markdown]
# ### Defines functions to translate a generated recipe back to a uniform string format

# %%
import re
new_line = ["•", "▪︎"]
headers = ["Ingredients", "Instructions"]
punctuation = [".", ","]
paranthesis = ["(", ")"]
    
def word2idx(word):
    return vocab.vocab[word].index

def idx2word(idx):
    return vocab.index2word[idx]

def indices2sentences(sentence): #Converts a vectorized recipe back to a unifrom string formatting.
    s = ""
    prev_title = False
    prev_word = ""
    for idx in sentence:
        word = str(idx2word(idx))
        if idx2word(idx) in headers:
            s+= "\n\n" + word
        elif idx2word(idx) in new_line:
            s+= "\n" + word
        elif idx2word(idx) == "Title":
            s+= "\n" + word + " "
            prev_title = True
        elif prev_word == "." or prev_word in new_line:
            s+= " " + word.capitalize() 
        else:
            if idx2word(idx) not in punctuation and not prev_title:
                s+= " " + word
            else:
                s+= word
                prev_title = False
       
        prev_word = word
    s = re.sub(r'(\s([?,.!"]))|(?<=\[|\()(.*?)(?=\)|\])', lambda x: x.group().strip(), s)

    return(s)

# %%
def sentences2indices(indices): #Converts a vectorized recipe back to strings
    index = [] 
    for idx in indices:
        index.append(word2idx(idx))
    return index

def tokens2sentences(tokens):
    return indices2sentences(sentences2indices(tokens))

# %% [markdown]
# ### Use the model to generate recipes

# %%
def generate_text(model, start_string, temperature):
    text_generated = []
    num_generate = 140

    # Converting our start string to numbers (vectorizing)
    input_eval = [word2idx(s) for s in start_string]
    input_eval = tf.expand_dims(input_eval, 0)


    # Here set batch size == 1
    model.reset_states()

    for i in range(num_generate):
        predictions = model(input_eval)
        # remove the batch dimension
        predictions = tf.squeeze(predictions, 0)

        #Ppredict the next word returned by the model
        predictions = predictions / temperature
        predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()

        # Feed the predicted word as the next input to the model
        input_eval = tf.expand_dims([predicted_id], 0)

        text_generated.append(idx2word(predicted_id))

    return (start_string + text_generated)

# %% [markdown]
# Initializes a progress bar for debug purposes

# %%
from IPython.display import HTML, display
import time

def progress(value, max=100):
    return HTML("""
        <progress
            value='{value}'
            max='{max}',
            style='width: 100%'
        >
            {value}
        </progress>
    """.format(value=value, max=max))

# %% [markdown]
# Loop to generate multiple recipes and save to file

# %%
import pickle
headers = ["Title","Ingredients", "Instructions"]

count = 0


def generateRecipes(temp, k, print_recipe=False):
  out = display(progress(0, k), display_id=True)
    
  generated_recipes = []

  for i in range(0, k):
      try:
        rec = generate_text(model_prediction, start_string=["Title"], temperature=temp)
        generated_recipes.append(tokens2sentences(rec))
      except:
        print("Faied to generate recipe")
        
      out.update(progress(i, k)) #Progress bar
      if print_recipe:
        print(tokens2sentences(rec))
        print("---------------------------------------")


  with open("/content/drive/MyDrive/Colab files/Output/generated_recipes" + str(temp) + ".txt", "wb") as fp:   #Pickling
        pickle.dump(generated_recipes, fp)

  print("Recipes written to file: " + "generated_recipes" + str(temp) + ".txt")
  return generated_recipes

# %%
generateRecipes(temp=1.2, k=1000, print_recipe=False)

# %%
temp = [1.2, 1.4, 1.0]

for t in temp:
  generateRecipes(temp=t, k=1000)
# Out:
#         <progress
#             value='999'
#             max='1000',
#             style='width: 100%'
#         >
#             999
#         </progress>
# Recipes written to file: generated_recipes1.2.txt
#         <progress
#             value='999'
#             max='1000',
#             style='width: 100%'
#         >
#             999
#         </progress>
# Recipes written to file: generated_recipes1.4.txt
#         <progress
#             value='999'
#             max='1000',
#             style='width: 100%'
#         >
#             999
#         </progress>
# Faied to generate recipe
# Recipes written to file: generated_recipes1.0.txt

# %% [markdown]
# #Evaluation

# %%
def parseSections(s_list):
    s = s_list.split()
    sub1 = s_list.split("Ingredients")
    sub2 = sub1[1].split("Instructions")
    title = sub1[0].replace("Title", "").replace("\n", "")
    ingredients = sub2[0].replace("Ingredients", "").replace("•", ",")
    if len(sub2) == 2:
        instructions = sub2[1].replace("Instructions", "").replace("\n", " ")
        return (title, ingredients, instructions)
    return (None, None, None)

# %% [markdown]
# Check if recipe contains Title, Ingredients, Instructions

# %%
def evaluateRecipe(recipes):
  score = 0
  for rec in recipes:
    temp_score = 0
    title, ingredients, instructions = parseSections(rec)
    if title and ingredients and instructions:
      #temp_score += 0.5
      tokens = rec.split()
      keyword = tokens[1]
      if keyword in title:
        temp_score += 1
    #print(temp_score)
      else:
        print("MISSING INGREDIENT IN INGREDIENTS")
        print(rec)
    score += temp_score
  return score/len(recipes)

evaluateRecipe(generated_recipes)
# Out:
# 1.0

# %% [markdown]
# ## Evaluation
# 1. Recipe should contain Title, Ingredients, Instructions
# 2. Recipes that contains ingredients in the title should also exists in the Ingredients.
# 3. Ingredients mentioned in the instructions should also exist in the Ingredients.

# %% [markdown]
# Load the ingredients dataset

# %%
import spacy
import numpy as np
import en_core_web_lg
import pandas as pd
nlp = en_core_web_lg.load()

#Source https://dominikschmidt.xyz/simplified-recipes-1M/
with np.load('/content/drive/MyDrive/Colab files/simplified-recipes-1M.npz', allow_pickle=True) as data:
    ingredients = data['ingredients']
print(type(ingredients))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# #### Convert ingredients from numpy.ndarray to list.str

# %%
def numpyToList(l):
    ingredients = []
    for i in l:
      ingredients.append(str(i))
    return ingredients

ingredients_list = numpyToList(ingredients)
print(type(ingredients_list))
# Out:
# <class 'list'>

# %%
for ing in ingredients_list[:5]:
  print(ing)
# Out:
# salt
# pepper
# butter
# garlic
# sugar

# %% [markdown]
# #### Disable unused NLP piplines to increase performance.

# %%
disabled = nlp.disable_pipes("ner", "parser")

# %% [markdown]
# ### Clean ingredients dataset to only contain base-ingredients (nouns) (e.g. only "chicken" and not "boneless chicken").

# %%
color = ["red", "brown", "black", "white", "green", "yellow", "blue"] #Colors is identified as NOUNS by the nlp() so a manual list was needed.
bad_pos = ["ADJ", "VERB", "ADVERB"]
#Bad words are words that have missclassified p
bad_words = ["mochi", "confit", "morsels", "carcass", "color", "flavouring", "claws", "calories", "brazil", "alcohol", "splenda", "franks","colors", "season", "dry", "glazed", "smoke", "smoked", "salted", "mix", "fat", "ingredients", "a", "mix", "ingredients", "vegetable", "an", "st", "m", "halfandhalf", "easy", "white", "roasted", "blend", "quick", "asian","half", "soft", "ground", "iron","chile","wild","plastic","blue","clean","dried","extra","yellow","indian","spring","chiles","steamer","mediterranean","swiss","smooth","pink","hand","waxed","instant","rich","prepared","blended","sponge","hands","combined","bottle","smoked","spam","smoking","flavor"]

def filterNonIngredients(ingredients_list):
    for i in ingredients_list:
      if len(i.split()) > 1:
        ingredients_list.remove(i)
      else:
        doc = nlp(i)
        for token in doc:
          if token.pos_ in bad_pos or token.text.lower() in color or token.text.lower() in bad_words or token.is_stop:
            print(i, end=", ")
            ingredients_list.remove(i)
    return ingredients_list

prev = 0
while len(ingredients_list) != prev:
    prev = len(ingredients_list)
    ingredients_list = filterNonIngredients(ingredients_list)

print("\n\n" + "Ingredients removed: " + str(len(ingredients) - len(ingredients_list)))
print("Updated number of ingredients in list: " + str(len(ingredients_list)))
# Out:
# ground, sliced, brown, vegetable, packed, extra, boneless, black, toasted, green, red, shortening, more, bottle, flavor, other, chiles, unbleached, mix, filling, flavored, concentrate, preserves, chunky, splenda, spring, blend, raw, organic, natural, soft, asian, flaked, distilled, season, wholewheat, franks, fresh, whole, artificial, swiss, wild, clean, no, ingredients, much, hand, indian, pasteurized, plastic, colors, mexicorn, curds, confit, sole, spam, alcohol, mediterranean, bleached, carcass, iron, squirt, mochi, st, m, claws, white, kosher, unsweetened, dressing, instant, roasted, dry, prepared, a, halfandhalf, chile, curry, chopped, quick, salted, smooth, crumbles, blue, pink, batter, imported, leaving, turkish, concentrated, rub, papayas, dehydrated, easy, unrefined, smoke, calories, sicilian, rich, steamer, garnish, yellow, sweetened, half, blanched, any, fat, savory, carbonated, sponge, combined, brazil, citric, color, vegan, morsels,
#
# Ingredients removed: 2638
# Updated number of ingredients in list: 862
# list

# %% [markdown]
# ###Change each ingredient into its singular form
# - Also removes false ingredients, e.g. soup which most likely are the result of a recipe not an ingredient in the recipe.

# %% [markdown]
# Reads false_ingredients_list from file. These ingredients are manually picked, after producing the frequency list at the end of this file

# %%
import csv
false_ingredients_list = []
with open('/content/drive/MyDrive/Colab files/false_ing.csv', 'r') as fd:
    reader = csv.reader(fd)
    for row in reader:
        if row != []:
          false_ingredients_list.append(row[0])

print(false_ingredients_list)
print("Length of false ingredients list:", len(false_ingredients_list))
# Out:
# ['accent', 'accompaniment', 'american', 'bagel', 'baguette', 'baker', 'base', 'bread', 'breast', 'broiler', 'broth', 'brownie', 'browning', 'buffalo', 'cake', 'casing', 'chutney', 'coleslaw', 'cookie', 'croissant', 'crostini', 'crust', 'cupcake', 'custard', 'cutlet', 'dairy', 'dough', 'dripping', 'dumpling', 'ear', 'essence', 'fl', 'flavor', 'flavoring', 'flavour', 'frosting', 'glaze', 'gluten', 'granola', 'gravy', 'greens', 'green', 'guacamole', 'hummus', 'iceberg', 'icing', 'leaf', 'loaf', 'marinade', 'mousse', 'msg', 'muffin', 'oatmeal', 'palm', 'pancake', 'paneer', 'partially', 'protein', 'pudding', 'pulp', 'purple', 'roast', 'roll', 'round', 'salsa', 'sandiwch', 'seasoning', 'seed', 'shortbread', 'silver', 'skin', 'slaw', 'sorbet', 'soup', 'spice', 'stew', 'stuffing', 'swede', 'temperature', 'toast', 'topping', 'twist', 'vegetable', 'vegetarian', 'veggie', 'vinaigrette', 'waffle', 'salad', 'fruit', 'pesto', 'crema', 'puree', 'sauce', 'sandwitch', 'meatball', 'meatloaf', 'fiber', 'tart', 'cracker', 'burger', 'fish', 'powder']
# Length of false ingredients list: 102

# %%
import inflect
p = inflect.engine()

new=[]
count = 0
exceptions_list = ["asparagus", "chips", "citrus", "couscous", "lemongrass", "oranges", "schnapps", "watercres", "leaves"]

ingredients_list_cleaned = []
def toSingular(token):
  token_singular = str(p.singular_noun(token.text.lower()))
  if token_singular != "False":
    ingredient = token_singular
  else:
    ingredient = token.text.lower()
  return ingredient

for i, ing in enumerate(ingredients_list):
  token = nlp(ing)
  if token.text.lower() in exceptions_list:
    ingredient = token.text.lower()
  else:
    ingredient = toSingular(token)
  
  if ingredient not in false_ingredients_list:
    ingredients_list_cleaned.append(ingredient)
    if ingredient != token.text.lower():
      count +=1


print("Plural words changed to singular:", count)
print("Lenght of old ingredients list:", len(ingredients_list))
print("Lenght of cleaned ingredients list:", len(ingredients_list_cleaned))
ingredients_list_cleaned[:10]
# Out:
# Plural words changed to singular: 154
# Lenght of old ingredients list: 862
# Lenght of cleaned ingredients list: 757
# ['salt',
#  'pepper',
#  'butter',
#  'garlic',
#  'sugar',
#  'flour',
#  'onion',
#  'water',
#  'olive',
#  'egg']

# %% [markdown]
# #### Disable "tagger" pipeline since it's no longer used.

# %%
if len(disabled) == 2:
    disabled += nlp.disable_pipes("tagger")

# %% [markdown]
# Load training set

# %%
df_train = []
with open("/content/drive/MyDrive/Colab files/df_filtered.txt", 'rb') as fp:
      df_train = pickle.load(fp)

# %%
import random
df_train = random.sample(df_train, len(df_train)-1)
len(df_train)
# Out:
# 91007

# %%
#salads_list = ["lettuce", "spinach", "romaine", "cabbage", "lettuce", "kale", "escarole", "endive"]

# %% [markdown]
# #Code for evaluation metric

# %%
ingredients_found = []

def checkForIngredients(token):
    global ingredients_found
    ing_found = False
    if token.is_alpha and not token.is_stop:
        ingredient = toSingular(token)

        if ingredient in ingredients_list_cleaned:
            ingredients_found.append(ingredient)
            ing_found = True

    if ing_found:
      return True
    else:
      return False


def allToSingular(header):
  words = []
  new_header = []

  for token in header:
    if token.text != " ":
      token_singular = str(p.singular_noun(token.text.lower()))
  
      if token_singular != "False":
        words.append(token_singular)
      else:
        words.append(token.text.lower())

  return words

ingredients_not_found = []
title_without_ing = 0 #Counts number of recipes that are not considered in the evaluation metric

def checkCond(header1, header2):
    global ingredients_found
    global ingredients_not_found
    global title_without_ing
    check = False
    doc = nlp(header1)
    doc2 = nlp(header2)
    score = 0
    ing_count = 0
    header2 = allToSingular(doc2) #Converts all ingredients into singular format

    for token in doc:
        if token.text != " ":
          if checkForIngredients(token):
              token_singular = toSingular(token)
              if token_singular == "vinaigrette":
                  token_singular = "vinegar"
              
              if token_singular in header2: 
                  score += 1
              else:
                  ingredients_not_found.append(token_singular)
              ing_count +=1

    if ing_count == 0:
      title_without_ing += 1 
      final_score = 1
    elif score == 0:
      final_score = 0
    else:
      final_score = score/ing_count 
    return final_score

# %% [markdown]
# Cleans ingredient list from verbs as ingredients. Verbs should only exist together with a ingredient noun eg. Green Pepper (VERB, NOUN).

# %% [markdown]
# ### Try the evaluation where ingredients identified in "Title" are crosschecked with the "Ingredients" section.
# Initially use this to identify ingredients in ingrediest_list that are not
# base ingredients. For example, "soup" is not really an ingredient, but something that is made with ingredients.

# %%
from IPython.display import clear_output

headers = ["Title", "Ingredients", "Instructions"]

def parseSections2(s_list):
    try:
      s = s_list.split()
 
      sub1 = s_list.split("Ingredients")
      sub2 = sub1[1].split("Instructions")
      title = sub1[0].replace("Title", "").replace("\n", "")
      ingredients = sub2[0].replace("Ingredients", "").replace("•", ",")

      if len(sub2) == 2:
          instructions = sub2[1].replace("Instructions", "").replace("\n", " ")
       
          return (title, ingredients, instructions)
    except:
      print(s_list)
      return (None, None, None)

def countX(lst, x):
    count = 0
    for ele in lst:
        if (ele == x):
            count = count + 1
    return count

def checkHeaders(recipe):
    s_list = recipe.split()
    missing_header = False
    sample_count = 0
    score = 0
    for h in headers:
      count = countX(s_list, h)
      #if count > 1:
        #print(count)
      if count > 0:
        score +=1
        sample_count+=count
      else:
        return 0.0

    return (score/sample_count)


def evaluateAndFilter(df):
    global ingredients_found
    global ingredients_not_found
    out = display(progress(0, len(df)-1), display_id=True)
  
    count = 0
    score1, score2, score3 = 0, 0, 0
    score_tot, score1_tot, score2_tot, score3_tot = 0 ,0 ,0, 0

    ingredients_found = []
    ingredients_not_found = []
    for i, row in enumerate(df):
        score1 = checkHeaders(row)
        score1_tot += score1
        if score1 > 0:
          try:
            title, ingredients, instructions = parseSections2(row)
            score2 = checkCond(title, ingredients) #Checks that title contains an ingredients, and that this ingredient exists in the ingredients section.
            score3 = checkCond(instructions, ingredients) #Checks that any ingredients mentioned in the instruction, exists in the ingredients section.
          except:
            pass
        #else:
            #print(row)

        score_tot += (score1 + score2 + score3) / 3
        score2_tot += score2
        score3_tot += score3
        
        out.update(progress(i, len(df)-1)) #Progress bar

    print("Score 1:", round(score1_tot/len(df), 2))
    print("Score 2:", round(score2_tot/len(df), 2))
    print("Score 3:", round(score3_tot/len(df), 2))
    print("Final Score: ", round(score_tot/len(df), 2))
    return df

# %%
import pickle
with open("/content/drive/MyDrive/Colab files/Output/generated_recipes1.4.txt", 'rb') as fp:
      df_generated_1_4 = pickle.load(fp)

with open("/content/drive/MyDrive/Colab files/Output/generated_recipes1.2.txt", 'rb') as fp:
      df_generated_1_2 = pickle.load(fp)

with open("/content/drive/MyDrive/Colab files/Output/generated_recipes1.0.txt", 'rb') as fp:
      df_generated_1_0 = pickle.load(fp)

with open("/content/drive/MyDrive/Colab files/Output/generated_recipes0.6.txt", 'rb') as fp:
      df_generated_0_6 = pickle.load(fp)



print(len(df_generated_1_4))
print(len(df_generated_1_2))
print(len(df_generated_1_0))
print(len(df_generated_0_6))
# Out:
# 1000
# 1000
# 999
# 999

# %%
print("\nTemperature 1_4")
evaluateAndFilter(df_generated_1_4.copy())

print("Temperature 1.2")
evaluateAndFilter(df_generated_1_2.copy())

print("Temperature 1.0")
evaluateAndFilter(df_generated_1_0.copy())

print("\nTemperature 0.6")
evaluateAndFilter(df_generated_0_6.copy())
# Out:
# Temperature 1_4
#         <progress
#             value='999'
#             max='999',
#             style='width: 100%'
#         >
#             999
#         </progress>
# Score 1: 0.82
# Score 2: 0.42
# Score 3: 0.2
# Final Score:  0.48
# Temperature 1.2
#         <progress
#             value='999'
#             max='999',
#             style='width: 100%'
#         >
#             999
#         </progress>
# Score 1: 0.89
# Score 2: 0.52
# Score 3: 0.3
# Final Score:  0.57
# Temperature 1.0
#         <progress
#             value='998'
#             max='998',
#             style='width: 100%'
#         >
#             998
#         </progress>
# Score 1: 0.91
# Score 2: 0.59
# Score 3: 0.39
# Final Score:  0.63
#
# Temperature 0.6
#         <progress
#             value='998'
#             max='998',
#             style='width: 100%'
#         >
#             998
#         </progress>
# Score 1: 0.88
# Score 2: 0.63
# Score 3: 0.54
# Final Score:  0.68
# ["\n\nTitle mediterranean squid stew\n\nIngredients\n• 1 pound eggplant, 10x15-inch or cut into 1/2-inch pieces\n• 2 tablespoons olive oil\n• 1 cup diced onion\n• 2 garlic cloves, machaca, shallow-fry in 1 or 2 pieces\n• 1 cup crushed tomatoes\n• 1/4 cup chopped fresh oregano leaves\n• 1 tablespoon fresh oregano leaves\n• 1 teaspoon salt\n• 1/2 teaspoon pepper\n• 1 medium white onion, arugula-mango, kadai, d'orschwihr, protrudes out of the tomatoes\n• 1 teaspoon chopped garlic\n• 1 can white beans\n• 2 tablespoons chopped fresh oregano leaves\n• 1 teaspoon salt\n• 2 teaspoons ground black pepper\n• 2 teaspoons ground white pepper\n• 1 teaspoon ground cumin\n• 1 teaspoon ground coriander\n• 1 teaspoon ground cumin\n• 1 tablespoon fresh oregano leaves\n• 1 cup red wine",
#  '\n\nTitle linguini with clams and manila clams\n\nIngredients\n• 4 cups linguini\n• 3 tablespoons extra-virgin olive oil\n• 3 cloves garlic, 20-inch long razor clams\n• 4 manila clams\n• 2 pounds mussels\n• 1 teaspoon crushed red pepper\n• 1 teaspoon salt\n• 1/2 teaspoon pepper\n• 1 teaspoon chopped fresh chives\n• 1/2 teaspoon seafood seasoning\n• 1 cup bread crumbs\n\nInstructions\n▪︎ Bring a large pot of salted water to a boil. Add pasta and cook until tender but still firm to the bite, tre, jasmati pasta is usually 3 or 4 to 5 minutes. Reserve.\n▪︎ In a large pot heat oil over medium heat. Add shallots and garlic and cook until soft. Add shallots and cook until soft and translucent. Add mirin wine and mirin and',
#  "\n\nTitle quick 'n ' corny hoecakes\n\nIngredients\n• 1 cup all-purpose flour\n• 1 teaspoon salt\n• 1/2 teaspoon baking powder\n• 1 teaspoon sugar\n• 2 tablespoons yellow cornmeal\n• 1/2 teaspoon baking soda\n• 1/2 teaspoon baking powder\n• 1/2 teaspoon baking soda\n• 1 egg\n• 1 cup buttermilk\n• 1 egg, re-plug\n\nInstructions\n▪︎ Put the flour, suagr and egg whites into the pie spice mix, silverbeet is recommended to the liquid. Stir in the beer, automatic egg. Taste for seasoning and add salt., sterilized, 11-cup food processor, appreciate powder, ready to serve.\n▪︎ To serve, tomate over some hot pepper flakes, sugar-flour and shake out the garlic salt. Rub the minced onion and garlic into the pea mixture to coat the",
#  '\n\nTitle clams casino\n\nIngredients\n• 4 red bell peppers, cinnamon-caramel peppers, 3-\xadquart shell, coffeehouse tops trimmed\n• 2 yellow bell peppers, ghraybeh shells on\n• 4 tablespoons butter\n• 1 small onion, pancetta-balsamic\n• 2 tablespoons finely chopped fresh parsley\n• 2 teaspoons chopped fresh thyme leaves\n• 2 teaspoons finely chopped parsley\n• 2 teaspoons finely chopped fresh thyme leaves\n• 1 teaspoon finely chopped fresh oregano leaves\n• 1 tablespoon chopped fresh parsley leaves\n• 1/2 teaspoon finely chopped fresh marjoram leaves\n• 1 teaspoon finely chopped fresh thyme leaves\n• Salt and freshly ground black pepper\n• 2 tablespoons extra-virgin olive oil\n\nInstructions\n▪︎ Preheat the broiler.\n▪︎ In a medium saucepan, spinach-stuffed portobellos ), côco with paring knife or in the shells. Set aside.\n▪︎ Melt butter',
#  '\n\nTitle mexican corn pudding\n\nIngredients\n• 1 can creamed corn\n• 1 cup chopped yellow onions\n• 1 pkg. Corn muffin mix\n• 1/2 cup milk\n• 2 cups corn muffin mix\n• Milk\n• 1 pkg. Frozen corn\n• 1 cup chopped onions\n• 1 cup chopped canned chipotle peppers in adobo\n• 1 pkg. Cream cheese, pillsbury®refrigerated chicken soup\n• 1 1/2 cups shredded monterey jack cheese\n• 2 cups corn kernels, rag and kernels cut into small ears\n• 1 pkg. Yellow corn muffin mix\n• 2 cups shredded monterey jack cheese\n• 1 cup thinly sliced yellow onions\n• 1 cup chopped celery\n• 1 tablespoon chopped garlic\n• 1 tablespoon chopped fresh cilantro leaves\n• 1 cup shredded cheddar cheese\n• 1/4 cup chopped fresh cilantro\n\nInstructions\n▪︎ Preheat oven',
#  '\n\nTitle mango-ginger smoothie\n\nIngredients\n• 1 ripe banana, 4-cup or other ripe, scatter half cut into chunks\n• 1 1/2 cups lowfat plain yogurt\n• 2 tablespoons orange juice\n• 1 tablespoon ginger, herb-fried\n• 1 tablespoon fresh mint leaves\n• 1/3 cup lowfat vanilla yogurt\n• 1/2 cup lowfat buttermilk\n• 1/4 cup lowfat yogurt\n\nInstructions\n▪︎ Watch how to make this recipe.\n▪︎ In a blender, evan blender, pocket-of-time to pop rims in a blender, kendra up to form a smooth, moving a spatula between a layer of the bottom of the blender. Blend for 1 minute, premade and freeze for up to 2 months.\n▪︎ In a blender, garlic-cilantro with yogurt, 26-inch ice, moyo. Using a metal spoon, tossed quickly into the',
#  '\n\nTitle potato parathas\n\nIngredients\n• 1 cup vegetable oil\n• 1 large spanish onion, malta\n• 1 teaspoon salt\n• 1 teaspoon black pepper\n• 1 teaspoon turmeric\n• 1/2 teaspoon ground allspice\n• 1/2 teaspoon ground cloves\n• 1/2 teaspoon ground cumin\n• 1/2 teaspoon ground coriander\n• 1/4 teaspoon ground cloves\n• 1/4 teaspoon turmeric\n• 1 cup water\n• 1 cup sour cream\n• 2 carrots, garnalen or 2 tablespoons brine from the can\n• 1 head garlic, choco-nut dough, freezer, tarro chips\n\nInstructions\n▪︎ Heat oil in a large saucepan. Add onion and chili powder and cook until hot, reubens down. Add chili powder and season with salt and pepper. Cook for 1 minute. Add the hot sauce, lj to the hot vegetable oil. Add',
#  '\n\nTitle pork tenderloin with apricot brandy\n\nIngredients\n• 2 tablespoons irvine spices supreme seasoning\n• 1 pork tenderloin\n• Salt and pepper\n\nInstructions\n▪︎ Preheat oven to 400 degrees f.\n▪︎ In a small bowl, resurrector by hand, confederate shallots and sage. Set aside.\n▪︎ Rub the seasoned pork tenderloins with olive oil and season with salt and pepper. Place the tenderloin in a roasting pan. Roast for 2 hours. Remove and allow to cool.\n▪︎ When the pork is cool, mentaiko with the skin and place in a large pan. Add a splash of brandy sauce to loosen and turn over. Roast for another 20 minutes.\n▪︎ Serve with sweet and sour sauce on the side., turkey-roasting pan, lentil-potato\n• 1 tablespoon vegetable oil\n•',
#  '\n\nTitle flaming blast of lime hot clam sauce\n\nIngredients\n• 1 1/2 pounds fresh green or red bell peppers\n• 1 jalapeno pepper, cognac, chicken-lentil fat or other small green bell peppers\n• 1 tablespoon fresh lime juice\n• 1 teaspoon worcestershire sauce\n• 1/2 teaspoon salt\n• 1 teaspoon fresh ground black pepper\n• 1 garlic clove, i.e., 200f down broken with blade steaks to blend all together.\n\nInstructions\n▪︎ Combine peppers, 3.4-ounce baking sheet, orange-colored fresh lime juice, david and keep shaking the pan. Heat a grill pan on medium-high heat.\n▪︎ Lightly coat the grill with olive oil and place on the grill, 68 to five minutes on each side.\n▪︎ Allow peppers to rest for about 10 minutes before serving., cocoon bags\n•',
#  '\n\nTitle quiche lorraine\n\nIngredients\n• 2 egg yolks\n• 1 tablespoon butter\n• 1 tablespoon all-purpose flour\n• 1 cup milk\n• 2 cups half-and-half\n• 8 ounces sharp cheddar\n• 1 cup grated gruyere\n• 1 tablespoon butter\n• Salt and pepper\n• 2 cups grated gruyere cheese\n• 1 cup grated parmesan\n• 1 cup grated parmesan\n\nInstructions\n▪︎ Preheat oven to 400 degrees f.\n▪︎ Melt butter in a saucepan over low heat, underripe and pureed. Add flour, carnaroli and add milk in saucepan. Reduce heat and simmer until thickened, light-green spots on bottom of the pan.\n▪︎ In a saucepan, musterdsoep or english bacon remove the saucepan from the heat and add the cream cheese, neely-tini, schrager, americain and salt and pepper to taste. Place the',
#  '\n\nTitle smoked sea bass with lime and lime\n\nIngredients\n• 1 pound boneless, cavolo percent of salt\n• 1 cup freshly squeezed lime juice\n• 1 tablespoon freshly ground black pepper\n• 2 tablespoons white wine vinegar\n• 2 tablespoons chopped fresh cilantro\n• 4 tablespoons salted butter\n• 1 tablespoon chopped fresh cilantro\n• 1 tablespoon chopped fresh cilantro\n\nInstructions\n▪︎ Watch how to make this recipe.\n▪︎ For the ceviche in a large bowl, trunk the skillet, kidney and the second side.\n▪︎ Place the fish on a plate and let rest for 30 minutes.\n▪︎ Combine the mayonnaise, vegi, lockhart all of the ingredients except for the butter in a small bowl. Mix well. Pour the lime butter over the fish and sprinkle with salt.\n▪︎ For',
#  '\n\nTitle sauerbraten 101\n\nIngredients\n• 6 to 8 medium or 6 pounds beef shin meat, monument or flank steak\n• 1 piece ginger, zest-parsley mixture\n• 1 to 2 red onion, best-tasting, 292 and\n• 1 teaspoon salt\n• 1 teaspoon black pepper\n• 1 tablespoon ground ginger\n• 2 cups beef stock\n• 1 cup apple cider vinegar\n• 1 cup water\n• 2 tablespoons brown sugar\n• 1 tablespoon ground coriander\n• 2 tablespoons butter\n• 2 tablespoons white vinegar\n• 2 tablespoons sugar\n• 1 tablespoon worcestershire sauce\n• 2 tablespoons red wine vinegar\n• 1 tablespoon fresh ginger, blanches from sodium, pork-sweet, petpitas\n• 1 large block of red leaf lettuce\n• 2 ounces pepper jack cheese\n• 4 beef lettuce leaves\n• Lettuce leaf\n\nInstructions\n▪︎ In a large',
#  "\n\nTitle sweet and chunky plum cobbler\n\nIngredients\n• 2 plums, sopressata\n• 1/2 cup sugar\n• 1/2 cup water\n• 1/4 cup peach nectar\n• 1/4 cup heavy cream\n• 1 tablespoon butter, calorie or dark brown sugar\n• 1 teaspoon vanilla extract\n\nInstructions\n▪︎ Preheat oven to 400 degrees f.\n▪︎ Place plums, sherry-garlic the water, how-to on a cookie sheet.\n▪︎ In a small saucepan, reserve½ out '' and sauces, garlic-ranch ice cream may need to be a well velvety.\n▪︎ In a small bowl, degre soup, ackee* ', grandmama fresh squeezed lemon juice, day-after-thanksgiving the ingredients to a work surface. If you have your own, faralle with a little extra sauce, unfurls on the side of the ice cream instead of the butter",
#  '\n\nTitle coquito\n\nIngredients\n• 1 egg\n• 1/2 cup sour cream\n• 1 can cream of coconut\n• 1 can coconut milk\n• 1 can coconut milk\n• 1 can crushed pineapple\n• 1 can coconut milk\n• Coconut milk, cake-decorating nice toothpick\n\nInstructions\n▪︎ Put coconut milk and coconut milk together in a blender and blend for 1 minute until smooth. Pour into glasses and garnish with coconut., 8–10-lb., napastyle., niblets 7/8 cup coconut milk\n▪︎ 1 1/2 cups flour\n▪︎ 3 tablespoons ghee, beanwiches with 1 tablespoon ghee or a cumin seed oil, destroyer and grind some fresh coriander seeds in a spice mill or on a course stovetop griddle with olive oil. Cook the corn in the oil for about 5 minutes, 5.3 times, pepperonatta',
#  '\n\nTitle beet-arugula salad with buttermilk-blue cheese dressing\n\nIngredients\n• 1 tablespoon cider vinegar\n• 3/4 tablespoon balsamic vinegar\n• 1/4 teaspoon salt\n• 1/4 teaspoon freshly ground black pepper\n• 1/3 cup extra-virgin olive oil\n• 1 small bag arugula greens, stockpot trimmed and chopped\n• 1 large bulb fennel, sangria-style and reserved\n• 1 small kohlrabi bulb, workspace, balsamic-fig, 223-235°f\n\nInstructions\n▪︎ In a small bowl, gulab stock is essential, alexia® blender a quarter of the way through.\n▪︎ In a small bowl, mahogany-colored if you are using, gribiche recipe.\n▪︎ In a small bowl, saus are substituting nectarine, mrs valley charcoal to the highest possible possible temperature.\n▪︎ When coals are hot, 5 minutes, nana or at once time, clockwatcher can be',
es, unseal the dough with a light knife, nibbles up on the side, bourguignon, kimchee*, ricard, on-hand bittersweet chocolate, testani, silpat-lined cream, criss-cross strips, sand-like\n• 3 cups duck stock\n• 1 cup heavy cream\n• 1 tablespoon freshly chopped thyme leaves\n• 2 teaspoons freshly ground black pepper\n• 1 tablespoon granulated onion\n• 1 tablespoon salt\n• 1 tablespoon black pepper\n• 1 tablespoon chopped',
#  '\n\nTitle crispy wonton cups with white bean sprouts and sprouts\n\nIngredients\n• 1 package frozen chopped spinach, straight-flat\n• 1 teaspoon sesame oil\n• 1 teaspoon minced garlic\n• 1/2 teaspoon fresh ground black pepper\n• 1 teaspoon salt\n• 1 teaspoon ground black pepper\n• 1 can mandarin orange segments, spaetzle-carrot, home-rendered or rice wine\n\nInstructions\n▪︎ Special equipment food processor\n▪︎ Heat the canola oil in a large pot or dutch oven. Add the sesame seeds and cook until fragrant, moka, supreme. Add the mushrooms, marion the mixture to coat. Add the garlic and saute until fragrant, oil-and-garlic mixture over in the pan. Add the soy sauce mixture, pronto™ peas and evaporate the liquid. Stir in the edamame, gain until well combined. Add the',
# ...
#  "\n\nTitle strawberry shortcake\n\nIngredients\n• 1 package frozen strawberries, two-spice vanilla pudding, spiciy 's pulp discarded\n• 1 pint heavy cream\n• 1 teaspoon orange-flavored liqueur, poppadums on a box\n• 1 teaspoon ground cinnamon\n• 1 pint heavy cream\n• 2 store-bought shortcakes or mini pretzels\n• 1 cup sugar\n• 1 cup all-purpose flour\n• 2 tablespoons sugar\n• 1/2 teaspoon ground cinnamon\n• 1/2 teaspoon ground nutmeg\n• 1/4 teaspoon ground cloves\n• 1/2 teaspoon salt\n• 1/2 pint unsalted butter\n• 1 tablespoon orange liqueur\n\nInstructions\n▪︎ Preheat oven to 375 degrees f.\n▪︎ In a large bowl, softens, italiano the cookies and the orange slices. In a large bowl, 3.5 wine, stef the orange or cream over the butter and the sugar. Add the orange juice and",
#  '\n\nTitle mango-ginger smoothie\n\nIngredients\n• 1 ripe banana\n• 1 ripe banana\n• 1 ripe banana\n• 1 banana\n• 1 small ripe banana\n• 1 ripe mango\n• 1 1/2 cups lowfat vanilla yogurt\n• 1 banana\n• 1 cup lowfat vanilla yogurt\n• 2 tablespoons lowfat vanilla yogurt\n• 2 tablespoons lowfat plain yogurt\n• 1 teaspoon ground ginger\n• 1 teaspoon ground cinnamon\n• 1 teaspoon freshly ground black pepper\n• 1 teaspoon vanilla extract\n• 1/4 teaspoon ground cinnamon\n• 1/2 teaspoon ground ginger\n• 1 teaspoon ground cinnamon\n• 1/4 teaspoon ground ginger\n• 1 banana, rosemary-lemon, giving sticks\n\nInstructions\n▪︎ For the banana smoothie put the mango, ounces/400 masala, 14-gram and sugar in a blender and blend until smooth. Add the banana, marsh or vanilla yogurt, crawler the',
#  "\n\nTitle quercyan apple cake\n\nIngredients\n• 1 1/2 ounce yeast\n• 1 tablespoon gram flour\n• 1 1/2 teaspoons active dry yeast\n• 2 tablespoons sugar\n• 1 1/2 teaspoons yeast\n• 1 1/2 teaspoons salt\n• 1/2 yeast\n• 1 1/2 cups warm water\n• 2 teaspoons yeast\n• 1 1/2 teaspoons granulated sugar\n• 2 tablespoons yeast\n• 6 cups canola oil\n• 1 cup warm water\n• 1/2 cup vegetable oil\n• 2 eggs\n• 2 tablespoons chopped onion\n• 1 tablespoon chopped chives\n\nInstructions\n▪︎ Place flour in a bowl and whisk 2/3 cup olive oil, 'aina the manufacturer 's instructions. Set aside.\n▪︎ In a large bowl, solgar the yeast to make the sponge. Using a fork, finally, urchin, schula, zia the the kitchen ball is delicious",
#  '\n\nTitle curried mussel soup with mussels\n\nIngredients\n• 2 pounds mussels\n• 1/2 cup olive oil\n• 1/2 cup onion, sausage-broth\n• 1/3 cup chopped chives\n• 1 teaspoon chopped fresh thyme leaves\n• 4 sprigs fresh thyme, hooley by a piece, coarse-mesh peeled stripes\n• 1 teaspoon chopped habanero chile\n• 1 teaspoon finely chopped fresh thyme leaves\n• 1 teaspoon finely chopped chives\n• 1 tablespoon chopped fresh thyme\n• 1 tablespoon chopped fresh parsley leaves\n• 1 tablespoon finely chopped fresh chives\n• Salt and freshly ground pepper\n\nInstructions\n▪︎ Heat the oven to 375 degrees f. to a medium skillet, shish wings, 1/3-pound racks, lychees, schweinebraten fish into small pieces.\n▪︎ In a large, seared-side up to 2 pounds, rode, vigorous or in a hot oven',
#  "\n\nTitle quinoa pilaf\n\nIngredients\n• 2 tablespoons butter\n• 1 onion, ga-prao yellow tail part, palm-sized pieces\n• 2 cups water\n• 1 1/2 cups fresh or frozen peas\n• 1 small onion, drying\n• 4 cups chicken broth\n• 1 bay leaf\n• 1 teaspoon ground white pepper\n• 1 1/2 teaspoons ground nutmeg\n• 1 cup chopped fresh parsley\n• 1 cup peas\n• 2 teaspoons kosher salt\n\nInstructions\n▪︎ Melt the butter in a large saucepan over medium heat. Add the onion and cook until soft. Add the onion and cook until soft. Add the broth, cheese-and-bacon mixture, 'buttered ' peas and basil. Cover and let the soup cook for 15 minutes, lemon-colored, bubbly and cooled, frenching like tender, clam or vegetable or paella.",
#  '\n\nTitle quinoa-corn salad\n\nIngredients\n\nInstructions\n▪︎ By 2 pints, roating an overhang on a 2 1/2- by 2-inches high, bun-length high heat. Add 1/3 cup water, pow with quinoa and quinoa. Cook until al dente, pre-wash stage releases. If not add more sriracha if too dry, barilla. Toss hot fruit with quinoa and coat with sesame oil. Malosh, parmesan-asparagus spread with a little cream on the parchment-lined baking sheets. Let sit in a 200 degree f oven. Repeat with remaining parchment. Top with dollop of caviar., quick-rise with a good drizzle motion for garnishing each appetizer with a wet toast, split-up\n\nIngredients\n• 2 tablespoons extra-virgin olive oil\n• 1 pound large sea scallops, chilis, more.add the shrimp\n• 2 to 3',
#  '\n\nTitle pilaf-style rice pilaf\n\nIngredients\n• 2 tablespoons extra-virgin olive oil\n• 1 teaspoon kosher salt\n• 2 large sprigs fresh thyme\n• 8 cups chicken broth\n• 2 cups long-grain rice\n• 1 3/4 teaspoons freshly squeezed lemon zest\n• 1/4 teaspoon freshly ground black pepper\n\nInstructions\n▪︎ Heat the olive oil in a large saucepan over medium heat. Add the rice and stir until the rice is coated with the oil is evenly coated. Add the thyme, freeze, tuaca** or for 5 minutes. Decrease the heat to low and cook for 10 minutes, 3/8 to 2 minutes. Reduce the heat to medium low. Continue cooking, tagin.\n▪︎ Reduce the heat to medium low, ghannouj. Continue cooking over medium heat until the rice is tender and the liquid',
#  '\n\nTitle caramelized onions\n\nIngredients\n• 2 pounds large red skinned onions\n• 1 stick butter\n• 1 tablespoon minced garlic\n• 1 tablespoon minced garlic\n• 1 tablespoon minced garlic\n• 1 cup yellow onion, spinach-rice, water\n• 1 tablespoon fresh thyme leaves\n• 2 tablespoons brown sugar\n• 1 tablespoon salt\n\nInstructions\n▪︎ Preheat oven to 350 degrees.\n▪︎ Coat the onions with the garlic butter, gnocchetti de petals, equator, ounces/65 cabbage, 13.5g roast and onions, stack.\n▪︎ In a saute pan, water-and-salt red and stirring until the color is gone. Add the olive oil and saute for 3 minutes. Stir in the onions and continue to saute for another few minutes. Add the sugar and continue to simmer until onions are tender. Season the water',
#  "\n\nTitle sunny 's delicious apple fritters\n\nIngredients\n• 1 cup all-purpose flour\n• 1 cup cricket flour\n• 1 tablespoon sugar\n• 1 teaspoon baking powder\n• 1 teaspoon kosher salt\n• 1/2 teaspoon ground cinnamon\n• 1/4 teaspoon ground nutmeg\n• 3 tablespoons unsalted butter, reipe\n• 1 large egg\n• 1 1/2 cups cold water\n• 1 apple, blackberry-mint syrup, brine, 8-to-10-inch 's, kir, roasted, light-colored sausage, by1-inch sheet, cup-shaped, 'crookies'\n• For waffle cones\n• 1 tablespoon ground cinnamon\n• 1 tablespoon sugar\n• 1 tablespoon cornstarch\n• 2 tablespoons water\n• 1 tablespoon brandy\n• 1 tablespoon rose water\n• 1 tablespoon dark chocolate sauce\n• 1 tablespoon brandy\n\nInstructions\n▪︎ Combine flour and salt in a medium bowl. Make a well in the center of",
#  "\n\nTitle strawberries jubilee cloud ''\n\nIngredients\n• 2 large egg yolks\n• 1 pint cherry pie filling\n• 2 tablespoons cream or half-and-half\n• 1 teaspoon vanilla extract\n• 1/4 teaspoon ground cinnamon\n• 1 cup heavy cream\n• 1 tablespoon confectioners ' sugar\n• 2 tablespoons fresh lemon juice\n• 1 tablespoon brandy\n• 1/8 teaspoon ground cinnamon\n• Smallest containers whipped cream\n\nInstructions\n▪︎ Whip cream and sugar until stiff peaks form. Beat in eggs and vanilla extract.\n▪︎ Add lemon curd, eaon with orange liqueur and stir for 30 seconds. Set aside.\n▪︎ To assemble\n▪︎ Cut each half into 4 wedges. Place a dollop of whipped cream on each dessert. Top with a dollop of whipped cream. Garnish with whipped cream and garnish with orange slices., accompanimentprovolone",
#  "\n\nTitle cioppino\n\nIngredients\n• 1 tablespoon olive oil\n• 1 small onion, kingsford's® clams, human, pluots, ryan removed, 6 times\n• 5 garlic cloves, berries.wi, cauliwraps\n• 4 large potatoes, zach through, 238 to the shells, lemon-butter, carignane\n• 2 tablespoons all-purpose flour\n• 1 teaspoon kosher salt\n• 1/2 teaspoon freshly ground black pepper\n• 1 cup white wine\n• 3 cups fish stock or clam juice\n• 2 tablespoons chopped fresh parsley\n• 1 tablespoon chopped fresh parsley\n\nInstructions\n▪︎ Heat the olive oil in a large pot or dutch oven over medium heat. Add the onion, galician-style, information sticks, kissed to the other side, electric-mixer and discard the garlic. Add the onion to the pot and cook over medium heat until",
#  '\n\nTitle chinese chicken soup with dumplings\n\nIngredients\n• 2 1/2 cups cooked, chestnuts**, beast cooked\n• 1 cup flour\n• 2 tablespoons chinese five-spice powder\n• 1 tablespoon granulated onion\n• 1 tablespoon dried parsley\n• 1 tablespoon sugar\n• 1 tablespoon sesame oil\n• 2 teaspoons salt\n• 1 teaspoon black pepper\n• 1 egg\n• 1/4 cup water\n• 1/4 cup flour\n• 1 egg yolk\n• 2 tablespoons vegetable oil\n• 1 1/2 cups finely chopped onions\n• 1 cup diced celery\n• 1 cup sliced shiitake mushrooms\n• 1 tablespoon minced ginger\n• 1 tablespoon minced ginger\n• 1/2 teaspoon salt\n\nInstructions\n▪︎ In a large bowl, tbsp/24 with a whisk, spinach-garlic fork, gianluca out of the onions, choriqueso, cocoa-chili flour with water as you would a egg in the',
#  '\n\nTitle sopaipillas with chocolate sauce\n\nIngredients\n• 2 cups flour\n• 2 tablespoons baking powder\n• 1 teaspoon baking soda\n• 1 teaspoon salt\n• Canola oil, munch your favorite brand, olek\n• 1 1/2 cups water\n• 1 cup buttermilk\n• 3 to 4 tablespoons butter, chocolate-butter, plantanos\n• 1 1/4 cups hot water\n• 1/2 cup heavy cream\n• 1/4 teaspoon nutmeg\n• 2 tablespoons water\n\nInstructions\n▪︎ In a bowl, averna mix the flour, poker-chip size, consisting of the liquid measuring cup, pepper.fold from the sides of the buttermilk, cheesed the cooker and slowly add the rest of the ingredients. Add the butter and mix until it is no longer lumpy.\n▪︎ Pour the batter into a large pot and pour in the heated water. When']

# %%
new_df = evaluateAndFilter(df_train[:1000].copy())
# Out:
#         <progress
#             value='999'
#             max='999',
#             style='width: 100%'
#         >
#             999
#         </progress>
# Avg Score 1: 1.0
# Avg Score 2: 0.8874166666666665
# Avg score 3: 0.8590190090678422
# Avg Full Score:  0.9154785585781712

# %%
print(len(new_df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-1339194882c2> in <module>()
# ----> 1 print(len(new_df))
#
# NameError: name 'new_df' is not defined

# %% [markdown]
# **NOTE:** BELOW PART IS DONE ONCE TO FILTER CERTAIN INGREDIENTS (PRODUCING THE FALSE_ING.CSV). THE EVALUATION ABOVE IS THEN WHAT IS USED FOR THE FINAL METRIC

# %% [markdown]
# ###Retrieve the frequency of ingredients that are identified both as negative and positive.
# - **Negative Ingredients** = Ingredients found in the title but NOT among the ingredients
# - **Positive Ingredients**   = Ingredients found in the title and among the ingredients

# %%
from collections import Counter
negative_ing_count = dict(Counter(ingredients_not_found).most_common())
positive_ing_count = dict(Counter(ingredients_found).most_common())

print("Not evaluated recipes: ", title_without_ing)
#print(word_counts)
print("Length Negative: ", len(negative_ing_count))
print(negative_ing_count)

print("Length Positive: ", len(positive_ing_count))
print(positive_ing_count)

print("Extracting all ingredients identified in recipe titles.")
print("Word, negative, positive ")
for word in negative_ing_count:
   #print(positive_word_counts[word])
 if positive_ing_count[word] is not None:
    print(str(word) + ", " + str(negative_ing_count[word]), ", " + str(positive_ing_count[word]))

#Extracting ingredients that was only identified in the title but not among the ingredients
for word in negative_ing_count:
   #print(positive_word_counts[word])
 if positive_ing_count[word] is not None:
    print(str(word) + ", " + str(negative_ing_count[word]), ", " + str(positive_ing_count[word]))
# Out:
# Not evaluated recipes:  2876
# Length Negative:  290
# {'salad': 662, 'sandwich': 144, 'burger': 69, 'herb': 66, 'pasta': 54, 'fruit': 49, 'tart': 49, 'caramel': 47, 'pesto': 44, 'chip': 43, 'chocolate': 42, 'ice': 42, 'fish': 39, 'biscuit': 39, 'risotto': 38, 'meatloaf': 37, 'citru': 36, 'cream': 35, 'crab': 32, 'chili': 30, 'relish': 29, 'fudge': 29, 'meatball': 29, 'cheese': 26, 'berry': 26, 'nut': 25, 'beef': 25, 'steak': 23, 'corn': 23, 'tea': 23, 'hummu': 20, 'seafood': 19, 'syrup': 19, 'stock': 18, 'lemonade': 17, 'meringue': 17, 'root': 16, 'candy': 16, 'jam': 16, 'sausage': 15, 'puree': 15, 'noodle': 14, 'pickle': 14, 'gluten': 14, 'topping': 14, 'aioli': 13, 'truffle': 13, 'gumbo': 12, 'eggnog': 11, 'rib': 11, 'crouton': 10, 'pastry': 10, 'potato': 10, 'skin': 10, 'coffee': 10, 'crumb': 10, 'tapenade': 10, 'ginger': 10, 'chickpea': 9, 'chicken': 9, 'meat': 9, 'butter': 9, 'adobo': 9, 'hamburger': 8, 'apple': 8, 'spaghetti': 8, 'polenta': 8, 'parmesan': 8, 'rice': 8, 'twist': 7, 'ganache': 7, 'jack': 7, 'icing': 7, 'flatbread': 7, 'shell': 7, 'crepe': 7, 'pig': 6, 'ricotta': 6, 'flavor': 6, 'wine': 6, 'round': 6, 'jelly': 6, 'ravioli': 6, 'tortilla': 6, 'soda': 6, 'pork': 6, 'cutlet': 6, 'game': 5, 'pepper': 5, 'turkey': 5, 'masala': 5, 'marshmallow': 5, 'sugar': 5, 'fondant': 5, 'champagne': 5, 'bun': 5, 'cracker': 5, 'bean': 5, 'ketchup': 5, 'focaccia': 5, 'mint': 5, 'love': 5, 'melon': 5, 'egg': 5, 'mayonnaise': 5, 'paste': 4, 'american': 4, 'meal': 4, 'pretzel': 4, 'tomato': 4, 'cactu': 4, 'gnocchi': 4, 'bouquet': 4, 'wafer': 4, 'caviar': 4, 'zest': 4, 'protein': 4, 'butterscotch': 3, 'honey': 3, 'silver': 3, 'chuck': 3, 'manicotti': 3, 'bacon': 3, 'brine': 3, 'pea': 3, 'dashi': 3, 'bouillon': 3, 'ponzu': 3, 'ham': 3, 'chipotle': 3, 'seasoning': 3, 'sherbet': 3, 'brioche': 3, 'cone': 3, 'harissa': 3, 'shrimp': 3, 'flower': 3, 'ragu': 3, 'macaroni': 3, 'powder': 3, 'kitchen': 3, 'water': 3, 'leaf': 3, 'malt': 3, 'anise': 3, 'grain': 3, 'lobster': 3, 'gingersnap': 3, 'prawn': 3, 'essence': 3, 'chiffonade': 2, 'blueberry': 2, 'lentil': 2, 'marmalade': 2, 'chai': 2, 'mushroom': 2, 'broccoli': 
'prawn': 16, 'popcorn': 16, 'wheat': 16, 'topping': 16, 'cider': 16, 'rum': 16, 'puree': 15, 'water': 15, 'leaf': 15, 'pita': 15, 'dijon': 15, 'chestnut': 15, 'jack': 14, 'sherry': 14, 'butterscotch': 14, 'turnip': 14, 'okra': 14, 'hen': 14, 'crumb': 14, 'catfish': 13, 'marshmallow': 13, 'plantain': 13, 'shell': 13, 'cod': 13, 'gumbo': 13, 'grit': 13, 'ravioli': 13, 'caviar': 13, 'wasabi': 13, 'cutlet': 13, 'poblano': 12, 'tilapia': 12, 'trout': 12, 'meat': 12, 'crouton': 12, 'vodka': 12, 'tapenade': 12, 'tortellini': 12, 'loin': 12, 'jicama': 12, 'grain': 12, 'game': 11, 'port': 11, 'paprika': 11, 'cornmeal': 11, 'champagne': 11, 'miso': 11, 'crepe': 11, 'escarole': 11, 'chard': 10, 'shiitake': 10, 'hamburger': 10, 'peppermint': 10, 'cocoa': 10, 'cardamom': 10, 'nectarine': 10, 'skin': 10, 'espresso': 10, 'venison': 10, 'ketchup': 10, 'limoncello': 9, 'tamarind': 9, 'porcini': 9, 'edamame': 9, 'coriander': 9, 'jelly': 9, 'liver': 9, 'tomatillo': 9, 'peppercorn': 9, 'anchovy': 9, 'br ...
# Extracting all ingredients identified in recipe titles.
# Word, negative, positive
# salad, 662 , 734
# sandwich, 144 , 155
# burger, 69 , 79
# herb, 66 , 81
# pasta, 54 , 153
# fruit, 49 , 73
# tart, 49 , 56
# caramel, 47 , 67
# pesto, 44 , 66
# chip, 43 , 106
# chocolate, 42 , 360
# ice, 42 , 95
# fish, 39 , 63
# biscuit, 39 , 45
# risotto, 38 , 41
# meatloaf, 37 , 38
# citru, 36 , 38
# cream, 35 , 264
# crab, 32 , 60
# chili, 30 , 92
# relish, 29 , 33
# fudge, 29 , 29
# meatball, 29 , 37
# cheese, 26 , 339
# berry, 26 , 49
# nut, 25 , 58
# beef, 25 , 174
# steak, 23 , 126
# corn, 23 , 161
# tea, 23 , 51
# hummu, 20 , 25
# seafood, 19 , 22
# syrup, 19 , 30
# stock, 18 , 18
# lemonade, 17 , 20
# meringue, 17 , 19
# root, 16 , 29
# candy, 16 , 20
# jam, 16 , 20
# sausage, 15 , 111
# puree, 15 , 15
# noodle, 14 , 66
# pickle, 14 , 22
# gluten, 14 , 26
# topping, 14 , 16
# aioli, 13 , 18
# truffle, 13 , 25
# gumbo, 12 , 13
# eggnog, 11 , 19
# rib, 11 , 75
# crouton, 10 , 12
# pastry, 10 , 24
# potato, 10 , 440
# skin, 10 , 10
# coffee, 10 , 37
# crumb, 10 , 14
# tapenade, 10 , 12
# ginger, 10 , 118
# chickpea, 9 , 42
# chicken, 9 , 726
# meat, 9 , 12
# butter, 9 , 185
# adobo, 9 , 9
# hamburger, 8 , 10
# apple, 8 , 218
# spaghetti, 8 , 48
# polenta, 8 , 23
# parmesan, 8 , 70
# rice, 8 , 232
# twist, 7 , 7
# ganache, 7 , 7
# jack, 7 , 14
# icing, 7 , 7
# flatbread, 7 , 8
# shell, 7 , 13
# crepe, 7 , 11
# pig, 6 , 7
# ricotta, 6 , 34
# flavor, 6 , 6
# wine, 6 , 43
# round, 6 , 7
# jelly, 6 , 9
# ravioli, 6 , 13
# tortilla, 6 , 34
# soda, 6 , 17
# pork, 6 , 206
# cutlet, 6 , 13
# game, 5 , 11
# pepper, 5 , 165
# turkey, 5 , 130
# masala, 5 , 7
# marshmallow, 5 , 13
# sugar, 5 , 54
# fondant, 5 , 5
# champagne, 5 , 11
# bun, 5 , 7
# cracker, 5 , 17
# bean, 5 , 279
# ketchup, 5 , 10
# focaccia, 5 , 6
# mint, 5 , 72
# love, 5 , 5
# melon, 5 , 17
# egg, 5 , 128
# mayonnaise, 5 , 29
# paste, 4 , 8
# american, 4 , 6
# meal, 4 , 4
# pretzel, 4 , 16
# tomato, 4 , 292
# cactu, 4 , 6
# gnocchi, 4 , 7
# bouquet, 4 , 4
# wafer, 4 , 4
# caviar, 4 , 13
# zest, 4 , 4
# protein, 4 , 6
# butterscotch, 3 , 14
# honey, 3 , 98
# silver, 3 , 4
# chuck, 3 , 4
# manicotti, 3 , 5
# bacon, 3 , 149
# brine, 3 , 3
# pea, 3 , 82
# dashi, 3 , 3
# bouillon, 3 , 3
# ponzu, 3 , 4
# ham, 3 , 88
# chipotle, 3 , 37
# seasoning, 3 , 3
# sherbet, 3 , 4
# brioche, 3 , 8
# cone, 3 , 5
# harissa, 3 , 5
# shrimp, 3 , 176
# flower, 3 , 6
# ragu, 3 , 4
# macaroni, 3 , 26
# powder, 3 , 5
# kitchen, 3 , 3
# water, 3 , 15
# leaf, 3 , 15
# malt, 3 , 6
# anise, 3 , 7
# grain, 3 , 12
# lobster, 3 , 40
# gingersnap, 3 , 6
# prawn, 3 , 16
# essence, 3 , 3
# chiffonade, 2 , 2
# blueberry, 2 , 70
# lentil, 2 , 37
# marmalade, 2 , 3
# chai, 2 , 3
# mushroom, 2 , 171
# broccoli, 2 , 79
# lemon, 2 , 205
# calamari, 2 , 5
# cabbage, 2 , 71
# pumpkin, 2 , 110
# base, 2 , 2
# cherry, 2 , 89
# gelatin, 2 , 3
# bay, 2 , 7
# linguine, 2 , 28
# kimchi, 2 , 6
# limoncello, 2 , 9
# amaretto, 2 , 7
# tostada, 2 , 7
# pita, 2 , 15
# filet, 2 , 4
# duck, 2 , 18
# milk, 2 , 21
# bagel, 2 , 4
# masa, 2 , 3
# purple, 2 , 8
# pimento, 2 , 5
# bitter, 2 , 4
# extract, 2 , 3
# onion, 2 , 144
# couscou, 2 , 35
# breast, 2 , 35
# molass, 2 , 20
# power, 2 , 2
# char, 2 , 6
# wiener, 2 , 2
# mascarpone, 2 , 17
# amber, 2 , 3
# cilantro, 2 , 32
# juice, 2 , 8
# liqueur, 2 , 7
# lime, 2 , 73
# lettuce, 2 , 23
# croissant, 2 , 5
# vodka, 1 , 12
# vermicelli, 1 , 4
# canela, 1 , 2
# breadstick, 1 , 2
# muesli, 1 , 1
# pimiento, 1 , 5
# buckwheat, 1 , 3
# beet, 1 , 34
# anisette, 1 , 1
# boursin, 1 , 3
# cucumber, 1 , 67
# barley, 1 , 20
# seed, 1 , 41
# udon, 1 , 2
# beetroot, 1 , 1
# coke, 1 , 1
# tuna, 1 , 87
# paneer, 1 , 1
# ale, 1 , 1
# baker, 1 , 1
# dal, 1 , 1
# marjoram, 1 , 8
# beer, 1 , 42
# quinoa, 1 , 41
# oreo, 1 , 2
# nutella, 1 , 1
# rutabaga, 1 , 3
# paprika, 1 , 11
# whiskey, 1 , 7
# nectarine, 1 , 10
# frito, 1 , 1
# cereal, 1 , 7
# popcorn, 1 , 16
# chard, 1 , 10
# sirloin, 1 , 5
# ziti, 1 , 3
# salmon, 1 , 149
# cauliflower, 1 , 45
# pastrami, 1 , 1
# link, 1 , 3
# orecchiette, 1 , 5
# liquid, 1 , 1
# chambord, 1 , 1
# shoyu, 1 , 1
# dill, 1 , 41
# gelatine, 1 , 1
# salami, 1 , 3
# chily, 1 , 1
# ear, 1 , 2
# tortellini, 1 , 12
# burgundy, 1 , 1
# flour, 1 , 6
# salt, 1 , 29
# raman, 1 , 4
# seaweed, 1 , 1
# bas, 1 , 20
# cashew, 1 , 18
# fusilli, 1 , 6
# sofrito, 1 , 1
# loin, 1 , 12
# shellfish, 1 , 2
# bacardi, 1 , 1
# coconut, 1 , 106
# velveeta, 1 , 5
# fillet, 1 , 18
# crema, 1 , 3
# giardiniera, 1 , 1
# asparagu, 1 , 71
# olive, 1 , 71
# eggplant, 1 , 55
# strawberry, 1 , 102
# almond, 1 , 102
# basmati, 1 , 4
# applesauce, 1 , 8
# zucchini, 1 , 86
# treacle, 1 , 1
# prosciutto, 1 , 33
# bulgur, 1 , 9
# basil, 1 , 84
# spinach, 1 , 134
# dairy, 1 , 1
# roe, 1 , 5
# sultana, 1 , 1
# cranberry, 1 , 104
# walnut, 1 , 72
# catfish, 1 , 13
# scallion, 1 , 21
# celery, 1 , 24
# aubergine, 1 , 1
# chanterelle, 1 , 7
# squash, 1 , 109
# chayote, 1 , 3
# cannellini, 1 , 5
# baguette, 1 , 6
# penne, 1 , 21
# salad, 662 , 734
# sandwich, 144 , 155
# burger, 69 , 79
# herb, 66 , 81
# pasta, 54 , 153
# fruit, 49 , 73
# tart, 49 , 56
# caramel, 47 , 67
# pesto, 44 , 66
# chip, 43 , 106
# chocolate, 42 , 360
# ice, 42 , 95
# fish, 39 , 63
# biscuit, 39 , 45
# risotto, 38 , 41
# meatloaf, 37 , 38
# citru, 36 , 38
# cream, 35 , 264
# crab, 32 , 60
# chili, 30 , 92
# relish, 29 , 33
# fudge, 29 , 29
# meatball, 29 , 37
# cheese, 26 , 339
# berry, 26 , 49
# nut, 25 , 58
# beef, 25 , 174
# steak, 23 , 126
# corn, 23 , 161
# tea, 23 , 51
# hummu, 20 , 25
# seafood, 19 , 22
# syrup, 19 , 30
# stock, 18 , 18
# lemonade, 17 , 20
# meringue, 17 , 19
# root, 16 , 29
# candy, 16 , 20
# jam, 16 , 20
# sausage, 15 , 111
# puree, 15 , 15
# noodle, 14 , 66
# pickle, 14 , 22
# gluten, 14 , 26
# topping, 14 , 16
# aioli, 13 , 18
# truffle, 13 , 25
# gumbo, 12 , 13
# eggnog, 11 , 19
# rib, 11 , 75
# crouton, 10 , 12
# pastry, 10 , 24
# potato, 10 , 440
# skin, 10 , 10
# coffee, 10 , 37
# crumb, 10 , 14
# tapenade, 10 , 12
# ginger, 10 , 118
# chickpea, 9 , 42
# chicken, 9 , 726
# meat, 9 , 12
# butter, 9 , 185
# adobo, 9 , 9
# hamburger, 8 , 10
# apple, 8 , 218
# spaghetti, 8 , 48
# polenta, 8 , 23
# parmesan, 8 , 70
# rice, 8 , 232
# twist, 7 , 7
# ganache, 7 , 7
# jack, 7 , 14
# icing, 7 , 7
# flatbread, 7 , 8
# shell, 7 , 13
# crepe, 7 , 11
# pig, 6 , 7
# ricotta, 6 , 34
# flavor, 6 , 6
# wine, 6 , 43
# round, 6 , 7
# jelly, 6 , 9
# ravioli, 6 , 13
# tortilla, 6 , 34
# soda, 6 , 17
# pork, 6 , 206
# cutlet, 6 , 13
# game, 5 , 11
# pepper, 5 , 165
# turkey, 5 , 130
# masala, 5 , 7
# marshmallow, 5 , 13
# sugar, 5 , 54
# fondant, 5 , 5
# champagne, 5 , 11
# bun, 5 , 7
# cracker, 5 , 17
# bean, 5 , 279
# ketchup, 5 , 10
# focaccia, 5 , 6
# mint, 5 , 72
# love, 5 , 5
# melon, 5 , 17
# egg, 5 , 128
# mayonnaise, 5 , 29
# paste, 4 , 8
# american, 4 , 6
# meal, 4 , 4
# pretzel, 4 , 16
# tomato, 4 , 292
# cactu, 4 , 6
# gnocchi, 4 , 7
# bouquet, 4 , 4
# wafer, 4 , 4
# caviar, 4 , 13
# zest, 4 , 4
# protein, 4 , 6
# butterscotch, 3 , 14
# honey, 3 , 98
# silver, 3 , 4
# chuck, 3 , 4
# manicotti, 3 , 5
# bacon, 3 , 149
# brine, 3 , 3
# pea, 3 , 82
# dashi, 3 , 3
# bouillon, 3 , 3
# ponzu, 3 , 4
# ham, 3 , 88
# chipotle, 3 , 37
# seasoning, 3 , 3
# sherbet, 3 , 4
# brioche, 3 , 8
# cone, 3 , 5
# harissa, 3 , 5
# shrimp, 3 , 176
# flower, 3 , 6
# ragu, 3 , 4
# macaroni, 3 , 26
# powder, 3 , 5
# kitchen, 3 , 3
# water, 3 , 15
# leaf, 3 , 15
# malt, 3 , 6
# anise, 3 , 7
# grain, 3 , 12
# lobster, 3 , 40
# gingersnap, 3 , 6
# prawn, 3 , 16
# essence, 3 , 3
# chiffonade, 2 , 2
# blueberry, 2 , 70
# lentil, 2 , 37
# marmalade, 2 , 3
# chai, 2 , 3
# mushroom, 2 , 171
# broccoli, 2 , 79
# lemon, 2 , 205
# calamari, 2 , 5
# cabbage, 2 , 71
# pumpkin, 2 , 110
# base, 2 , 2
# cherry, 2 , 89
# gelatin, 2 , 3
# bay, 2 , 7
# linguine, 2 , 28
# kimchi, 2 , 6
# limoncello, 2 , 9
# amaretto, 2 , 7
# tostada, 2 , 7
# pita, 2 , 15
# filet, 2 , 4
# duck, 2 , 18
# milk, 2 , 21
# bagel, 2 , 4
# masa, 2 , 3
# purple, 2 , 8
# pimento, 2 , 5
# bitter, 2 , 4
# extract, 2 , 3
# onion, 2 , 144
# couscou, 2 , 35
# breast, 2 , 35
# molass, 2 , 20
# power, 2 , 2
# char, 2 , 6
# wiener, 2 , 2
# mascarpone, 2 , 17
# amber, 2 , 3
# cilantro, 2 , 32
# juice, 2 , 8
# liqueur, 2 , 7
# lime, 2 , 73
# lettuce, 2 , 23
# croissant, 2 , 5
# vodka, 1 , 12
# vermicelli, 1 , 4
# canela, 1 , 2
# breadstick, 1 , 2
# muesli, 1 , 1
# pimiento, 1 , 5
# buckwheat, 1 , 3
# beet, 1 , 34
# anisette, 1 , 1
# boursin, 1 , 3
# cucumber, 1 , 67
# barley, 1 , 20
# seed, 1 , 41
# udon, 1 , 2
# beetroot, 1 , 1
# coke, 1 , 1
# tuna, 1 , 87
# paneer, 1 , 1
# ale, 1 , 1
# baker, 1 , 1
# dal, 1 , 1
# marjoram, 1 , 8
# beer, 1 , 42
# quinoa, 1 , 41
# oreo, 1 , 2
# nutella, 1 , 1
# rutabaga, 1 , 3
# paprika, 1 , 11
# whiskey, 1 , 7
# nectarine, 1 , 10
# frito, 1 , 1
# cereal, 1 , 7
# popcorn, 1 , 16
# chard, 1 , 10
# sirloin, 1 , 5
# ziti, 1 , 3
# salmon, 1 , 149
# cauliflower, 1 , 45
# pastrami, 1 , 1
# link, 1 , 3
# orecchiette, 1 , 5
# liquid, 1 , 1
# chambord, 1 , 1
# shoyu, 1 , 1
# dill, 1 , 41
# gelatine, 1 , 1
# salami, 1 , 3
# chily, 1 , 1
# ear, 1 , 2
# tortellini, 1 , 12
# burgundy, 1 , 1
# flour, 1 , 6
# salt, 1 , 29
# raman, 1 , 4
# seaweed, 1 , 1
# bas, 1 , 20
# cashew, 1 , 18
# fusilli, 1 , 6
# sofrito, 1 , 1
# loin, 1 , 12
# shellfish, 1 , 2
# bacardi, 1 , 1
# coconut, 1 , 106
# velveeta, 1 , 5
# fillet, 1 , 18
# crema, 1 , 3
# giardiniera, 1 , 1
# asparagu, 1 , 71
# olive, 1 , 71
# eggplant, 1 , 55
# strawberry, 1 , 102
# almond, 1 , 102
# basmati, 1 , 4
# applesauce, 1 , 8
# zucchini, 1 , 86
# treacle, 1 , 1
# prosciutto, 1 , 33
# bulgur, 1 , 9
# basil, 1 , 84
# spinach, 1 , 134
# dairy, 1 , 1
# roe, 1 , 5
# sultana, 1 , 1
# cranberry, 1 , 104
# walnut, 1 , 72
# catfish, 1 , 13
# scallion, 1 , 21
# celery, 1 , 24
# aubergine, 1 , 1
# chanterelle, 1 , 7
# squash, 1 , 109
# chayote, 1 , 3
# cannellini, 1 , 5
# baguette, 1 , 6
# penne, 1 , 21

# %% [markdown]
# #Extracting Negative Ingredients that does not occur in the Positive Ingredients

# %%
#Extracting ingredients that was only identified in the title but not among the ingredients
for word in negative_word_counts:
   #print(positive_word_counts[word])
  if word not in positive_word_counts:
      print(str(word) + ", " + str(negative_word_counts[word]))

# %%
ingredients_list_old = ingredients_list
